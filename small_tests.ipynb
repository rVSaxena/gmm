# %%
import torch
import torchaudio
from matplotlib import pyplot as plt

# %%
l=torchaudio.load("data/RB_ABUDHABI.wav")[0]

# %%
plt.plot(l[0])

# %%
data=l[0, 7*48000:100*48000]

# %%
plt.plot(data)
